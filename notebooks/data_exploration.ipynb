# %%
import pandas as pd
import ast
import json 

gold_set = pd.read_csv('../data/gold_set/LLM_ANNOTATES_GOLD_SET.csv')
gold_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 39 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   conversation_id                                     345 non-null    str
#  1   conversation                                        345 non-null    str
#  2   dialogue_like                                       326 non-null    float64
#  3   conversation_statistics_num_turns                   345 non-null    int64
#  4   conversation_statistics_num_user_turns              345 non-null    int64
#  5   conversation_statistics_avg_user_tokens             345 non-null    float64
#  6   conversation_statistics_avg_assistant_tokens        345 non-null    float64
#  7   conversation_statistics_conversation_lenght_tokens  345 non-null    int64
#  8   semantic_coherence_conversation_score               345 non-null    float64
# ...
